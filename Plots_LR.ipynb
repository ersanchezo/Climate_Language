# %%
library(ggplot2)

# %%
#Import dataframes
mean <- read.csv('Mean_A.csv')
med <- read.csv('Median_A.csv')

# %%
mean$stat <- rep('mean',nrow(mean))

med$stat <- rep('median',nrow(med))


df<-rbind(med,mean) 

df<-df[-c(1,8),]

plt_ar<-function(h,v){
ggplot(df, aes(x=h, y=v, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
    }

# %%
#Linear Regression Dorsal - Median

lm.fit1<-lm(dorsal.c_R~Temp, data=subset(df,stat=='median'))
summary(lm.fit1)
lm.fit2<-lm(dorsal.c_R~Prec, data=subset(df,stat=='median'))
summary(lm.fit2)
lm.fit3<-lm(dorsal.c_R~elevation, data=subset(df,stat=='median'))
summary(lm.fit3)
# Out:
# Call:
# lm(formula = dorsal.c_R ~ Temp, data = subset(df, stat == "median"))
#
# Residuals:
#       2       3       4       5       6       7
#  0.2520  0.3000  0.5781 -0.5919  0.2429 -0.7811
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.926698   0.843387   7.027  0.00216 **
# Temp        -0.004569   0.003799  -1.202  0.29548
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.6138 on 4 degrees of freedom
# Multiple R-squared:  0.2655,	Adjusted R-squared:  0.08189
# F-statistic: 1.446 on 1 and 4 DF,  p-value: 0.2955
# Call:
# lm(formula = dorsal.c_R ~ Prec, data = subset(df, stat == "median"))
#
# Residuals:
#       2       3       4       5       6       7
# -0.1244 -0.2500  0.8534 -0.3435  0.4974 -0.6328
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  5.5458453  0.5900260   9.399 0.000714 ***
# Prec        -0.0004006  0.0003625  -1.105 0.331105
# ---
# ...

# %%
#Linear Regression for Dorsal - Mean

lm.fit1<-lm(dorsal.c_R~Temp, data=subset(df,stat=='mean'))
summary(lm.fit1)
lm.fit2<-lm(dorsal.c_R~Prec, data=subset(df,stat=='mean'))
summary(lm.fit2)
lm.fit3<-lm(dorsal.c_R~elevation, data=subset(df,stat=='mean'))
summary(lm.fit3)
# Out:
# Call:
# lm(formula = dorsal.c_R ~ Temp, data = subset(df, stat == "mean"))
#
# Residuals:
#        9       10       11       12       13       14
#  1.35690  0.05681 -0.37045  0.68256 -0.66769 -1.05814
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.360987   1.502453   4.899  0.00805 **
# Temp        -0.008443   0.007042  -1.199  0.29667
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.002 on 4 degrees of freedom
# Multiple R-squared:  0.2644,	Adjusted R-squared:  0.08051
# F-statistic: 1.438 on 1 and 4 DF,  p-value: 0.2967
# Call:
# lm(formula = dorsal.c_R ~ Prec, data = subset(df, stat == "mean"))
#
# Residuals:
#        9       10       11       12       13       14
#  0.54503 -1.04673 -0.04832  0.90291  0.23008 -0.58298
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  7.0839053  0.7697014   9.203 0.000774 ***
# ...

# %%
#Linear Regression for Voiceless - Mean

lm.fit1<-lm(voiceless_R~Temp, data=subset(df,stat=='mean'))
summary(lm.fit1)
lm.fit2<-lm(voiceless_R~Prec, data=subset(df,stat=='mean'))
summary(lm.fit2)
lm.fit3<-lm(voiceless_R~elevation, data=subset(df,stat=='mean'))
summary(lm.fit3)
# Out:
# Call:
# lm(formula = voiceless_R ~ Temp, data = subset(df, stat == "mean"))
#
# Residuals:
#       9      10      11      12      13      14
#  2.9005 -1.8195 -1.7853  1.9951 -1.8018  0.5111
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 16.34508    3.54958   4.605  0.00999 **
# Temp        -0.03894    0.01664  -2.341  0.07931 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 2.366 on 4 degrees of freedom
# Multiple R-squared:  0.578,	Adjusted R-squared:  0.4725
# F-statistic: 5.479 on 1 and 4 DF,  p-value: 0.07931
# Call:
# lm(formula = voiceless_R ~ Prec, data = subset(df, stat == "mean"))
#
# Residuals:
#       9      10      11      12      13      14
#  0.4899 -5.0587  1.0840  4.0380 -1.2424  0.6892
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.75088    3.21195   3.347   0.0286 *
# Prec        -0.00158    0.00191  -0.827   0.4547
# ---
# ...

# %%
#Linear Regression Voiceless - Median

lm.fit1<-lm(voiceless_R~Temp, data=subset(df,stat=='median'))
summary(lm.fit1)
lm.fit2<-lm(voiceless_R~Prec, data=subset(df,stat=='median'))
summary(lm.fit2)
lm.fit3<-lm(voiceless_R~elevation, data=subset(df,stat=='median'))
summary(lm.fit3)
# Out:
# Call:
# lm(formula = voiceless_R ~ Temp, data = subset(df, stat == "median"))
#
# Residuals:
#       2       3       4       5       6       7
#  1.0586 -1.1905 -0.9662  0.9520 -0.9892  1.1353
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 12.106783   1.770898   6.837  0.00239 **
# Temp        -0.023897   0.007978  -2.995  0.04012 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 1.289 on 4 degrees of freedom
# Multiple R-squared:  0.6917,	Adjusted R-squared:  0.6146
# F-statistic: 8.973 on 1 and 4 DF,  p-value: 0.04012
# Call:
# lm(formula = voiceless_R ~ Prec, data = subset(df, stat == "median"))
#
# Residuals:
#       2       3       4       5       6       7
# -0.3146 -3.0211  1.1488  2.7361 -1.2926  0.7434
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  8.0073684  2.1178798   3.781   0.0194 *
# Prec        -0.0006585  0.0013012  -0.506   0.6394
# ---
# ...

# %%
#Linear Regression Uvular - Mean
lm.fit1<-lm(uvular.c_R~Temp, data=subset(df,stat=='mean'))
summary(lm.fit1)
lm.fit2<-lm(uvular.c_R~Prec, data=subset(df,stat=='mean'))
summary(lm.fit2)
lm.fit3<-lm(uvular.c_R~elevation, data=subset(df,stat=='mean'))
summary(lm.fit3)
# Out:
# Call:
# lm(formula = uvular.c_R ~ Temp, data = subset(df, stat == "mean"))
#
# Residuals:
#        9       10       11       12       13       14
# -0.05355  0.01646 -0.24071  0.28597 -0.13800  0.12984
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  2.031363   0.317108   6.406  0.00305 **
# Temp        -0.007814   0.001486  -5.258  0.00626 **
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.2114 on 4 degrees of freedom
# Multiple R-squared:  0.8736,	Adjusted R-squared:  0.842
# F-statistic: 27.65 on 1 and 4 DF,  p-value: 0.006263
# Call:
# lm(formula = uvular.c_R ~ Prec, data = subset(df, stat == "mean"))
#
# Residuals:
#        9       10       11       12       13       14
# -0.48658 -0.56321  0.38764  0.73494 -0.16185  0.08905
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)  0.7447514  0.5394216   1.381     0.24
# ...

# %%
#Voiceless~Temperature
ggplot(df, aes(x=Temp, y=voiceless_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=Temp, y=dorsal.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=Temp, y=uvular.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
#Precipitation
ggplot(df, aes(x=Prec, y=voiceless_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=Prec, y=dorsal.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=Prec, y=uvular.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
#Elevation
ggplot(df, aes(x=elevation, y=voiceless_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=elevation, y=dorsal.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title

# %%
ggplot(df, aes(x=Prec, y=uvular.c_R, label = macroareas, color=stat)) +
  geom_point() + geom_text(vjust = 0 , nudge_y = 0.05) + 
  geom_smooth(method=lm, se=FALSE, fullrange=TRUE)
# Out:
# plot without title
